# %%
patients_data = [
(1001,"Aarav Khan","Hyderabad",29,"Male","Gold","2023-01-10"),
(1002,"Priya Reddy","Bengaluru",34,"Female","Silver","2023-01-15"),
(1003,"Rahul Mehta","Mumbai",41,"Male","Gold","2023-02-02"),
(1004,"Sneha Kapoor","Delhi",26,"Female","Bronze","2023-02-18"),
(1005,"Kiran Patel","Ahmedabad",37,"Male","Silver","2023-03-01"),
(1006,"Ananya Das","Kolkata",31,"Female","Gold","2023-03-12"),
(1007,"Vikram Singh","Chennai",45,"Male","Bronze","2023-03-20"),
(1008,"Meera Nair","Kochi",28,"Female","Silver","2023-04-05"),
(1009,"Farhan Ali","Hyderabad",39,"Male","Gold","2023-04-15"),
(1010,"Divya Menon","Bengaluru",33,"Female","Silver","2023-04-21"),
(1011,"Arjun Iyer","Chennai",52,"Male","Gold","2023-05-01"),
(1012,"Neha Gupta","Delhi",25,"Female","Bronze","2023-05-11"),
(1013,"Sanjay Rao","Mumbai",48,"Male","Silver","2023-05-19"),
(1014,"Kavya Sharma","Hyderabad",30,"Female","Gold","2023-06-01"),
(1015,"Nikhil Verma","Pune",36,"Male","Silver","2023-06-12"),
(1016,"Ayesha Khan","Kolkata",27,"Female","Bronze","2023-06-20"),
(1017,"Manish Yadav","Lucknow",44,"Male","Gold","2023-07-05"),
(1018,"Pooja Shah","Ahmedabad",32,"Female","Silver","2023-07-18"),
(1019,"Rohan Nair","Kochi",40,"Male","Gold","2023-08-01"),
(1020,"Lakshmi Rao","Chennai",35,"Female","Silver","2023-08-14")
]
patients_columns = [
"patient_id","patient_name","city","age","gender","membership","registration_date"
]
patients_df = spark.createDataFrame(patients_data, patients_columns)
doctors_data = [
(201,"Dr Sameer Sharma","Cardiology","Hyderabad",1200),
(202,"Dr Kavita Iyer","Dermatology","Bengaluru",800),
(203,"Dr Imran Khan","Orthopedics","Mumbai",1500),
(204,"Dr Ramesh Reddy","Pediatrics","Delhi",900),
(205,"Dr Anita Mehta","Neurology","Hyderabad",2000),
(206,"Dr Joseph Mathew","Cardiology","Chennai",1300),
(207,"Dr Fatima Ali","Dermatology","Kolkata",850),
(208,"Dr Arvind Rao","Orthopedics","Bengaluru",1400),
(209,"Dr Leela Nair","Neurology","Kochi",1900),
(210,"Dr Ganesh Patil","General Medicine","Pune",700)
]
doctors_columns = [
"doctor_id","doctor_name","specialization","doctor_city","consultation_fee"
]
doctors_df = spark.createDataFrame(doctors_data, doctors_columns)
visits_data = [
(1,1001,201,"2024-03-01","Completed",2),
(2,1002,202,"2024-03-01","Completed",1),
(3,1003,203,"2024-03-02","Completed",3),
(4,1004,204,"2024-03-02","Pending",1),
(5,1005,206,"2024-03-03","Completed",2),
(6,1006,205,"2024-03-03","Completed",4),
(7,1007,207,"2024-03-04","Cancelled",1),
(8,1008,208,"2024-03-04","Completed",2),
(9,1009,201,"2024-03-05","Completed",1),
(10,1010,202,"2024-03-05","Completed",2),
(11,1011,205,"2024-03-06","Pending",3),
(12,1012,204,"2024-03-06","Completed",1),
(13,1013,203,"2024-03-07","Completed",2),
(14,1014,201,"2024-03-07","Completed",3),
(15,1015,210,"2024-03-08","Completed",1),
(16,1016,207,"2024-03-08","Cancelled",2),
(17,1017,209,"2024-03-09","Completed",4),
(18,1018,206,"2024-03-09","Completed",2),
(19,1019,209,"2024-03-10","Completed",3),
(20,1020,206,"2024-03-10","Pending",2),
(21,1001,205,"2024-03-11","Completed",3),
(22,1003,208,"2024-03-11","Completed",2),
(23,1006,201,"2024-03-12","Completed",1),
(24,1009,210,"2024-03-12","Completed",2),
(25,1014,202,"2024-03-13","Completed",1)
]
visits_columns = [
"visit_id","patient_id","doctor_id","visit_date","visit_status","tests_count"
]
visits_df = spark.createDataFrame(visits_data, visits_columns)

payments_data = [
(301,1,5200,"UPI","Paid"),
(302,2,2800,"Credit Card","Paid"),
(303,3,7500,"Cash","Paid"),
(304,4,2900,"UPI","Pending"),
(305,5,5300,"Debit Card","Paid"),
(306,6,10000,"Credit Card","Paid"),
(307,7,2850,"Cash","Cancelled"),
(308,8,5400,"UPI","Paid"),
(309,9,3200,"UPI","Paid"),
(310,10,4800,"Credit Card","Paid"),
(311,11,8000,"UPI","Pending"),
(312,12,2900,"Cash","Paid"),
(313,13,5500,"Credit Card","Paid"),
(314,14,7200,"UPI","Paid"),
(315,15,2700,"Debit Card","Paid"),
(316,16,4850,"Cash","Cancelled"),
(317,17,9900,"Credit Card","Paid"),
(318,18,5300,"UPI","Paid"),
(319,19,7900,"Debit Card","Paid"),
(320,20,5300,"UPI","Pending"),
(321,21,8000,"UPI","Paid"),
(322,22,5400,"Credit Card","Paid"),
(323,23,3200,"Cash","Paid"),
(324,24,4700,"UPI","Paid"),
(325,25,2800,"UPI","Paid")
]
payments_columns = [
"payment_id","visit_id","bill_amount","payment_mode","payment_status"
]
payments_df = spark.createDataFrame(payments_data, payments_columns)

# %%
patients_df.show()

doctors_df.show()

visits_df.show()

payments_df.show()
# Out:
# +----------+------------+---------+---+------+----------+-----------------+
# |patient_id|patient_name|     city|age|gender|membership|registration_date|
# +----------+------------+---------+---+------+----------+-----------------+
# |      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|
# |      1002| Priya Reddy|Bengaluru| 34|Female|    Silver|       2023-01-15|
# |      1003| Rahul Mehta|   Mumbai| 41|  Male|      Gold|       2023-02-02|
# |      1004|Sneha Kapoor|    Delhi| 26|Female|    Bronze|       2023-02-18|
# |      1005| Kiran Patel|Ahmedabad| 37|  Male|    Silver|       2023-03-01|
# |      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|
# |      1007|Vikram Singh|  Chennai| 45|  Male|    Bronze|       2023-03-20|
# |      1008|  Meera Nair|    Kochi| 28|Female|    Silver|       2023-04-05|
# |      1009|  Farhan Ali|Hyderabad| 39|  Male|      Gold|       2023-04-15|
# |      1010| Divya Menon|Bengaluru| 33|Female|    Silver|       2023-04-21|
# |      1011|  Arjun Iyer|  Chennai| 52|  Male|      Gold|       2023-05-01|
# |      1012|  Neha Gupta|    Delhi| 25|Female|    Bronze|       2023-05-11|
# |      1013|  Sanjay Rao|   Mumbai| 48|  Male|    Silver|       2023-05-19|
# |      1014|Kavya Sharma|Hyderabad| 30|Female|      Gold|       2023-06-01|
# |      1015|Nikhil Verma|     Pune| 36|  Male|    Silver|       2023-06-12|
# |      1016| Ayesha Khan|  Kolkata| 27|Female|    Bronze|       2023-06-20|
# |      1017|Manish Yadav|  Lucknow| 44|  Male|      Gold|       2023-07-05|
# |      1018|  Pooja Shah|Ahmedabad| 32|Female|    Silver|       2023-07-18|
# |      1019|  Rohan Nair|    Kochi| 40|  Male|      Gold|       2023-08-01|
# |      1020| Lakshmi Rao|  Chennai| 35|Female|    Silver|       2023-08-14|
# +----------+------------+---------+---+------+----------+-----------------+
#
# +---------+----------------+----------------+-----------+----------------+
# |doctor_id|     doctor_name|  specialization|doctor_city|consultation_fee|
# +---------+----------------+----------------+-----------+----------------+
# |      201|Dr Sameer Sharma|      Cardiology|  Hyderabad|            1200|
# |      202|  Dr Kavita Iyer|     Dermatology|  Bengaluru|             800|
# |      203|   Dr Imran Khan|     Orthopedics|     Mumbai|            1500|
# |      204| Dr Ramesh Reddy|      Pediatrics|      Delhi|             900|
# |      205|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|
# |      206|Dr Joseph Mathew|      Cardiology|    Chennai|            1300|
# |      207|   Dr Fatima Ali|     Dermatology|    Kolkata|             850|
# |      208|   Dr Arvind Rao|     Orthopedics|  Bengaluru|            1400|
# |      209|   Dr Leela Nair|       Neurology|      Kochi|            1900|
# |      210| Dr Ganesh Patil|General Medicine|       Pune|             700|
# +---------+----------------+----------------+-----------+----------------+
#
# +--------+----------+---------+----------+------------+-----------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|
# +--------+----------+---------+----------+------------+-----------+
# |       1|      1001|      201|2024-03-01|   Completed|          2|
# |       2|      1002|      202|2024-03-01|   Completed|          1|
# |       3|      1003|      203|2024-03-02|   Completed|          3|
# |       4|      1004|      204|2024-03-02|     Pending|          1|
# |       5|      1005|      206|2024-03-03|   Completed|          2|
# |       6|      1006|      205|2024-03-03|   Completed|          4|
# |       7|      1007|      207|2024-03-04|   Cancelled|          1|
# |       8|      1008|      208|2024-03-04|   Completed|          2|
# |       9|      1009|      201|2024-03-05|   Completed|          1|
# |      10|      1010|      202|2024-03-05|   Completed|          2|
# |      11|      1011|      205|2024-03-06|     Pending|          3|
# |      12|      1012|      204|2024-03-06|   Completed|          1|
# |      13|      1013|      203|2024-03-07|   Completed|          2|
# |      14|      1014|      201|2024-03-07|   Completed|          3|
# |      15|      1015|      210|2024-03-08|   Completed|          1|
# |      16|      1016|      207|2024-03-08|   Cancelled|          2|
# |      17|      1017|      209|2024-03-09|   Completed|          4|
# |      18|      1018|      206|2024-03-09|   Completed|          2|
# |      19|      1019|      209|2024-03-10|   Completed|          3|
# |      20|      1020|      206|2024-03-10|     Pending|          2|
# +--------+----------+---------+----------+------------+-----------+
# only showing top 20 rows
# +----------+--------+-----------+------------+--------------+
# |payment_id|visit_id|bill_amount|payment_mode|payment_status|
# +----------+--------+-----------+------------+--------------+
# |       301|       1|       5200|         UPI|          Paid|
# |       302|       2|       2800| Credit Card|          Paid|
# |       303|       3|       7500|        Cash|          Paid|
# |       304|       4|       2900|         UPI|       Pending|
# |       305|       5|       5300|  Debit Card|          Paid|
# |       306|       6|      10000| Credit Card|          Paid|
# |       307|       7|       2850|        Cash|     Cancelled|
# |       308|       8|       5400|         UPI|          Paid|
# |       309|       9|       3200|         UPI|          Paid|
# |       310|      10|       4800| Credit Card|          Paid|
# |       311|      11|       8000|         UPI|       Pending|
# |       312|      12|       2900|        Cash|          Paid|
# |       313|      13|       5500| Credit Card|          Paid|
# |       314|      14|       7200|         UPI|          Paid|
# |       315|      15|       2700|  Debit Card|          Paid|
# |       316|      16|       4850|        Cash|     Cancelled|
# |       317|      17|       9900| Credit Card|          Paid|
# |       318|      18|       5300|         UPI|          Paid|
# |       319|      19|       7900|  Debit Card|          Paid|
# |       320|      20|       5300|         UPI|       Pending|
# +----------+--------+-----------+------------+--------------+
# only showing top 20 rows

# %%
patients_df.printSchema()

doctors_df.printSchema()

visits_df.printSchema()

payments_df.printSchema()
# Out:
# root
#  |-- patient_id: long (nullable = true)
#  |-- patient_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- membership: string (nullable = true)
#  |-- registration_date: string (nullable = true)
#
# root
#  |-- doctor_id: long (nullable = true)
#  |-- doctor_name: string (nullable = true)
#  |-- specialization: string (nullable = true)
#  |-- doctor_city: string (nullable = true)
#  |-- consultation_fee: long (nullable = true)
#
# root
#  |-- visit_id: long (nullable = true)
#  |-- patient_id: long (nullable = true)
#  |-- doctor_id: long (nullable = true)
#  |-- visit_date: string (nullable = true)
#  |-- visit_status: string (nullable = true)
#  |-- tests_count: long (nullable = true)
#
# root
#  |-- payment_id: long (nullable = true)
#  |-- visit_id: long (nullable = true)
#  |-- bill_amount: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- payment_status: string (nullable = true)

# %%
patients_df.count()

doctors_df.count()

visits_df.count()

payments_df.count()
# Out:
# 25

# %%
patients_df.show(10)
# Out:
# +----------+------------+---------+---+------+----------+-----------------+
# |patient_id|patient_name|     city|age|gender|membership|registration_date|
# +----------+------------+---------+---+------+----------+-----------------+
# |      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|
# |      1002| Priya Reddy|Bengaluru| 34|Female|    Silver|       2023-01-15|
# |      1003| Rahul Mehta|   Mumbai| 41|  Male|      Gold|       2023-02-02|
# |      1004|Sneha Kapoor|    Delhi| 26|Female|    Bronze|       2023-02-18|
# |      1005| Kiran Patel|Ahmedabad| 37|  Male|    Silver|       2023-03-01|
# |      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|
# |      1007|Vikram Singh|  Chennai| 45|  Male|    Bronze|       2023-03-20|
# |      1008|  Meera Nair|    Kochi| 28|Female|    Silver|       2023-04-05|
# |      1009|  Farhan Ali|Hyderabad| 39|  Male|      Gold|       2023-04-15|
# |      1010| Divya Menon|Bengaluru| 33|Female|    Silver|       2023-04-21|
# +----------+------------+---------+---+------+----------+-----------------+
# only showing top 10 rows

# %%
patients_df.select(
    "patient_name",
    "city",
    "membership",
    "age"
).show()
# Out:
# +------------+---------+----------+---+
# |patient_name|     city|membership|age|
# +------------+---------+----------+---+
# |  Aarav Khan|Hyderabad|      Gold| 29|
# | Priya Reddy|Bengaluru|    Silver| 34|
# | Rahul Mehta|   Mumbai|      Gold| 41|
# |Sneha Kapoor|    Delhi|    Bronze| 26|
# | Kiran Patel|Ahmedabad|    Silver| 37|
# |  Ananya Das|  Kolkata|      Gold| 31|
# |Vikram Singh|  Chennai|    Bronze| 45|
# |  Meera Nair|    Kochi|    Silver| 28|
# |  Farhan Ali|Hyderabad|      Gold| 39|
# | Divya Menon|Bengaluru|    Silver| 33|
# |  Arjun Iyer|  Chennai|      Gold| 52|
# |  Neha Gupta|    Delhi|    Bronze| 25|
# |  Sanjay Rao|   Mumbai|    Silver| 48|
# |Kavya Sharma|Hyderabad|      Gold| 30|
# |Nikhil Verma|     Pune|    Silver| 36|
# | Ayesha Khan|  Kolkata|    Bronze| 27|
# |Manish Yadav|  Lucknow|      Gold| 44|
# |  Pooja Shah|Ahmedabad|    Silver| 32|
# |  Rohan Nair|    Kochi|      Gold| 40|
# | Lakshmi Rao|  Chennai|    Silver| 35|
# +------------+---------+----------+---+

# %%
doctors_df.select(
    "doctor_name",
    "specialization",
    "consultation_fee"
).show()
# Out:
# +----------------+----------------+----------------+
# |     doctor_name|  specialization|consultation_fee|
# +----------------+----------------+----------------+
# |Dr Sameer Sharma|      Cardiology|            1200|
# |  Dr Kavita Iyer|     Dermatology|             800|
# |   Dr Imran Khan|     Orthopedics|            1500|
# | Dr Ramesh Reddy|      Pediatrics|             900|
# |  Dr Anita Mehta|       Neurology|            2000|
# |Dr Joseph Mathew|      Cardiology|            1300|
# |   Dr Fatima Ali|     Dermatology|             850|
# |   Dr Arvind Rao|     Orthopedics|            1400|
# |   Dr Leela Nair|       Neurology|            1900|
# | Dr Ganesh Patil|General Medicine|             700|
# +----------------+----------------+----------------+

# %%
visits_df.filter(
    visits_df.visit_status == "Completed"
).show()
# Out:
# +--------+----------+---------+----------+------------+-----------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|
# +--------+----------+---------+----------+------------+-----------+
# |       1|      1001|      201|2024-03-01|   Completed|          2|
# |       2|      1002|      202|2024-03-01|   Completed|          1|
# |       3|      1003|      203|2024-03-02|   Completed|          3|
# |       5|      1005|      206|2024-03-03|   Completed|          2|
# |       6|      1006|      205|2024-03-03|   Completed|          4|
# |       8|      1008|      208|2024-03-04|   Completed|          2|
# |       9|      1009|      201|2024-03-05|   Completed|          1|
# |      10|      1010|      202|2024-03-05|   Completed|          2|
# |      12|      1012|      204|2024-03-06|   Completed|          1|
# |      13|      1013|      203|2024-03-07|   Completed|          2|
# |      14|      1014|      201|2024-03-07|   Completed|          3|
# |      15|      1015|      210|2024-03-08|   Completed|          1|
# |      17|      1017|      209|2024-03-09|   Completed|          4|
# |      18|      1018|      206|2024-03-09|   Completed|          2|
# |      19|      1019|      209|2024-03-10|   Completed|          3|
# |      21|      1001|      205|2024-03-11|   Completed|          3|
# |      22|      1003|      208|2024-03-11|   Completed|          2|
# |      23|      1006|      201|2024-03-12|   Completed|          1|
# |      24|      1009|      210|2024-03-12|   Completed|          2|
# |      25|      1014|      202|2024-03-13|   Completed|          1|
# +--------+----------+---------+----------+------------+-----------+

# %%
from pyspark.sql.functions import col
visits_df.filter(
    col("visit_status") == "Pending"
).show()
# Out:
# +--------+----------+---------+----------+------------+-----------+
# |visit_id|patient_id|doctor_id|visit_date|visit_status|tests_count|
# +--------+----------+---------+----------+------------+-----------+
# |       4|      1004|      204|2024-03-02|     Pending|          1|
# |      11|      1011|      205|2024-03-06|     Pending|          3|
# |      20|      1020|      206|2024-03-10|     Pending|          2|
# +--------+----------+---------+----------+------------+-----------+

# %%
patients_df.filter(
    patients_df.city.isin("Hyderabad","Bengaluru")
).show()

# %%
doctors_df.filter(
    doctors_df.consultation_fee > 1000
).show()
# Out:
# +---------+----------------+--------------+-----------+----------------+
# |doctor_id|     doctor_name|specialization|doctor_city|consultation_fee|
# +---------+----------------+--------------+-----------+----------------+
# |      201|Dr Sameer Sharma|    Cardiology|  Hyderabad|            1200|
# |      203|   Dr Imran Khan|   Orthopedics|     Mumbai|            1500|
# |      205|  Dr Anita Mehta|     Neurology|  Hyderabad|            2000|
# |      206|Dr Joseph Mathew|    Cardiology|    Chennai|            1300|
# |      208|   Dr Arvind Rao|   Orthopedics|  Bengaluru|            1400|
# |      209|   Dr Leela Nair|     Neurology|      Kochi|            1900|
# +---------+----------------+--------------+-----------+----------------+

# %%
from pyspark.sql.functions import *
patients_df = patients_df.withColumn(
    "registration_date",
    to_date("registration_date")
)
visits_df = visits_df.withColumn("visit_date", to_date("visit_date"))

# %%
visits_df = visits_df.withColumn(
    "test_cost",
    col("tests_count") * 500
)

# %%
visits_df = visits_df.withColumn(
    "estimated_total_bill",
    col("test_cost") + 2000
)

# %%
patients_df = patients_df.withColumn(
    "age_category",
    when(col("age") < 30, "Young")
    .when(col("age") < 45, "Adult")
    .otherwise("Senior")
)

# %%
patients_df.show()
# Out:
# +----------+------------+---------+---+------+----------+-----------------+------------+
# |patient_id|patient_name|     city|age|gender|membership|registration_date|age_category|
# +----------+------------+---------+---+------+----------+-----------------+------------+
# |      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|       Young|
# |      1002| Priya Reddy|Bengaluru| 34|Female|    Silver|       2023-01-15|       Adult|
# |      1003| Rahul Mehta|   Mumbai| 41|  Male|      Gold|       2023-02-02|       Adult|
# |      1004|Sneha Kapoor|    Delhi| 26|Female|    Bronze|       2023-02-18|       Young|
# |      1005| Kiran Patel|Ahmedabad| 37|  Male|    Silver|       2023-03-01|       Adult|
# |      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|       Adult|
# |      1007|Vikram Singh|  Chennai| 45|  Male|    Bronze|       2023-03-20|      Senior|
# |      1008|  Meera Nair|    Kochi| 28|Female|    Silver|       2023-04-05|       Young|
# |      1009|  Farhan Ali|Hyderabad| 39|  Male|      Gold|       2023-04-15|       Adult|
# |      1010| Divya Menon|Bengaluru| 33|Female|    Silver|       2023-04-21|       Adult|
# |      1011|  Arjun Iyer|  Chennai| 52|  Male|      Gold|       2023-05-01|      Senior|
# |      1012|  Neha Gupta|    Delhi| 25|Female|    Bronze|       2023-05-11|       Young|
# |      1013|  Sanjay Rao|   Mumbai| 48|  Male|    Silver|       2023-05-19|      Senior|
# |      1014|Kavya Sharma|Hyderabad| 30|Female|      Gold|       2023-06-01|       Adult|
# |      1015|Nikhil Verma|     Pune| 36|  Male|    Silver|       2023-06-12|       Adult|
# |      1016| Ayesha Khan|  Kolkata| 27|Female|    Bronze|       2023-06-20|       Young|
# |      1017|Manish Yadav|  Lucknow| 44|  Male|      Gold|       2023-07-05|       Adult|
# |      1018|  Pooja Shah|Ahmedabad| 32|Female|    Silver|       2023-07-18|       Adult|
# |      1019|  Rohan Nair|    Kochi| 40|  Male|      Gold|       2023-08-01|       Adult|
# |      1020| Lakshmi Rao|  Chennai| 35|Female|    Silver|       2023-08-14|       Adult|
# +----------+------------+---------+---+------+----------+-----------------+------------+

# %%
patients_df = patients_df.withColumn("membership_priority", when(col("membership") == "Gold", "high").when(col("membership") == "silver", "medium").otherwise("low"))

# %%
visits_df = visits_df.withColumn(
    "visit_priority",
    when(col("visit_status") == "Pending","High")
    .when(col("visit_status") == "Completed","Medium")
    .otherwise("Low")
)

# %%
payments_df = payments_df.withColumn(
    "high_bill_flag",
    when(col("bill_amount") > 7000,"YES")
    .otherwise("NO")
)

# %%
patients_df = patients_df.withColumnRenamed(
    "patient_name",
    "full_name"
)

# %%
visits_df = visits_df.drop("test_cost")

# %%
patient_visits_df = patients_df.join(
    visits_df,
    "patient_id"
)

# %%
visit_doctor_df = visits_df.join(
    doctors_df,
    "doctor_id"
)

# %%
visit_payment_df = visits_df.join(
    payments_df,
    "visit_id"
)

# %%
final_df = patients_df.join(visits_df, "patient_id").join(doctors_df, "doctor_id").join(payments_df, "visit_id")
display(final_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>visit_id</th><th>doctor_id</th><th>patient_id</th><th>full_name</th><th>city</th><th>age</th><th>gender</th><th>membership</th><th>registration_date</th><th>age_category</th><th>membership_priority</th><th>visit_date</th><th>visit_status</th><th>tests_count</th><th>estimated_total_bill</th><th>visit_priority</th><th>doctor_name</th><th>specialization</th><th>doctor_city</th><th>consultation_fee</th><th>payment_id</th><th>bill_amount</th><th>payment_mode</th><th>payment_status</th><th>high_bill_flag</th></tr></thead><tbody><tr><td>1</td><td>201</td><td>1001</td><td>Aarav Khan</td><td>Hyderabad</td><td>29</td><td>Male</td><td>Gold</td><td>2023-01-10</td><td>Young</td><td>high</td><td>2024-03-01</td><td>Completed</td><td>2</td><td>3000</td><td>Medium</td><td>Dr Sameer Sharma</td><td>Cardiology</td><td>Hyderabad</td><td>1200</td><td>301</td><td>5200</td><td>UPI</td><td>Paid</td><td>NO</td></tr><tr><td>2</td><td>202</td><td>1002</td><td>Priya Reddy</td><td>Bengaluru</td><td>34</td><td>Female</td><td>Silver</td><td>2023-01-15</td><td>Adult</td><td>low</td><td>2024-03-01</td><td>Completed</td><td>1</td><td>2500</td><td>Medium</td><td>Dr Kavita Iyer</td><td>Dermatology</td><td>Bengaluru</td><td>800</td><td>302</td><td>2800</td><td>Credit Card</td><td>Paid</td><td>NO</td></tr><tr><td>3</td><td>203</td><td>1003</td><td>Rahul Mehta</td><td>Mumbai</td><td>41</td><td>Male</td><td>Gold</td><td>2023-02-02</td><td>Adult</td><td>high</td><td>2024-03-02</td><td>Completed</td><td>3</td><td>3500</td><td>Medium</td><td>Dr Imran Khan</td><td>Orthopedics</td><td>Mumbai</td><td>1500</td><td>303</td><td>7500</td><td>Cash</td><td>Paid</td><td>YES</td></tr><tr><td>
# |Sneha Kapoor|    Delhi| Dr Ramesh Reddy|      Pediatrics|     Pending|       2900|
# | Kiran Patel|Ahmedabad|Dr Joseph Mathew|      Cardiology|   Completed|       5300|
# |  Ananya Das|  Kolkata|  Dr Anita Mehta|       Neurology|   Completed|      10000|
# |Vikram Singh|  Chennai|   Dr Fatima Ali|     Dermatology|   Cancelled|       2850|
# |  Meera Nair|    Kochi|   Dr Arvind Rao|     Orthopedics|   Completed|       5400|
# |  Farhan Ali|Hyderabad|Dr Sameer Sharma|      Cardiology|   Completed|       3200|
# | Divya Menon|Bengaluru|  Dr Kavita Iyer|     Dermatology|   Completed|       4800|
# |  Arjun Iyer|  Chennai|  Dr Anita Mehta|       Neurology|     Pending|       8000|
# |  Neha Gupta|    Delhi| Dr Ramesh Reddy|      Pediatrics|   Completed|       2900|
# |  Sanjay Rao|   Mumbai|   Dr Imran Khan|     Orthopedics|   Completed|       5500|
# |Kavya Sharma|Hyderabad|Dr Sameer Sharma|      Cardiology|   Completed|       7200|
# |Nikhil Verma|     Pune| Dr Ganesh Patil|General Medicine|   Completed|       2700|
# | Ayesha Khan|  Kolkata|   Dr Fatima Ali|     Dermatology|   Cancelled|       4850|
# |Manish Yadav|  Lucknow|   Dr Leela Nair|       Neurology|   Completed|       9900|
# |  Pooja Shah|Ahmedabad|Dr Joseph Mathew|      Cardiology|   Completed|       5300|
# |  Rohan Nair|    Kochi|   Dr Leela Nair|       Neurology|   Completed|       7900|
# | Lakshmi Rao|  Chennai|Dr Joseph Mathew|      Cardiology|     Pending|       5300|
# +------------+---------+----------------+----------------+------------+-----------+
# only showing top 20 rows

# %%
doc = final_df.filter(col("city") != col("doctor_city"))
display(doc)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>visit_id</th><th>doctor_id</th><th>patient_id</th><th>full_name</th><th>city</th><th>age</th><th>gender</th><th>membership</th><th>registration_date</th><th>age_category</th><th>membership_priority</th><th>visit_date</th><th>visit_status</th><th>tests_count</th><th>estimated_total_bill</th><th>visit_priority</th><th>doctor_name</th><th>specialization</th><th>doctor_city</th><th>consultation_fee</th><th>payment_id</th><th>bill_amount</th><th>payment_mode</th><th>payment_status</th><th>high_bill_flag</th></tr></thead><tbody><tr><td>5</td><td>206</td><td>1005</td><td>Kiran Patel</td><td>Ahmedabad</td><td>37</td><td>Male</td><td>Silver</td><td>2023-03-01</td><td>Adult</td><td>low</td><td>2024-03-03</td><td>Completed</td><td>2</td><td>3000</td><td>Medium</td><td>Dr Joseph Mathew</td><td>Cardiology</td><td>Chennai</td><td>1300</td><td>305</td><td>5300</td><td>Debit Card</td><td>Paid</td><td>NO</td></tr><tr><td>6</td><td>205</td><td>1006</td><td>Ananya Das</td><td>Kolkata</td><td>31</td><td>Female</td><td>Gold</td><td>2023-03-12</td><td>Adult</td><td>high</td><td>2024-03-03</td><td>Completed</td><td>4</td><td>4000</td><td>Medium</td><td>Dr Anita Mehta</td><td>Neurology</td><td>Hyderabad</td><td>2000</td><td>306</td><td>10000</td><td>Credit Card</td><td>Paid</td><td>YES</td></tr><tr><td>7</td><td>207</td><td>1007</td><td>Vikram Singh</td><td>Chennai</
Dr Joseph Mathew|      Cardiology|    Chennai|            1300|       318|       5300|         UPI|          Paid|            NO|
# |      19|      209|      1019|  Rohan Nair|    Kochi| 40|  Male|      Gold|       2023-08-01|       Adult|               high|2024-03-10|   Completed|          3|                3500|        Medium|   Dr Leela Nair|       Neurology|      Kochi|            1900|       319|       7900|  Debit Card|          Paid|           YES|
# |      21|      205|      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|       Young|               high|2024-03-11|   Completed|          3|                3500|        Medium|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|       321|       8000|         UPI|          Paid|           YES|
# |      22|      208|      1003| Rahul Mehta|   Mumbai| 41|  Male|      Gold|       2023-02-02|       Adult|               high|2024-03-11|   Completed|          2|                3000|        Medium|   Dr Arvind Rao|     Orthopedics|  Bengaluru|            1400|       322|       5400| Credit Card|          Paid|            NO|
# |      23|      201|      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|       Adult|               high|2024-03-12|   Completed|          1|                2500|        Medium|Dr Sameer Sharma|      Cardiology|  Hyderabad|            1200|       323|       3200|        Cash|          Paid|            NO|
# |      24|      210|      1009|  Farhan Ali|Hyderabad| 39|  Male|      Gold|       2023-04-15|       Adult|               high|2024-03-12|   Completed|          2|                3000|        Medium| Dr Ganesh Patil|General Medicine|       Pune|             700|       324|       4700|         UPI|          Paid|            NO|
# |      25|      202|      1014|Kavya Sharma|Hyderabad| 30|Female|      Gold|       2023-06-01|       Adult|               high|2024-03-13|   Completed|          1|                2500|        Medium|  Dr Kavita Iyer|     Dermatology|  Bengaluru|             800|       325|       2800|         UPI|          Paid|            NO|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+

# %%
final_df.filter(
    (col("visit_status") == "Pending") &
    (col("payment_status") == "Pending")
).show()
# Out:
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# |visit_id|doctor_id|patient_id|   full_name|   city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|     doctor_name|specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# |       4|      204|      1004|Sneha Kapoor|  Delhi| 26|Female|    Bronze|       2023-02-18|       Young|                low|2024-03-02|     Pending|          1|                2500|          High| Dr Ramesh Reddy|    Pediatrics|      Delhi|             900|       304|       2900|         UPI|       Pending|            NO|
# |      11|      205|      1011|  Arjun Iyer|Chennai| 52|  Male|      Gold|       2023-05-01|      Senior|               high|2024-03-06|     Pending|          3|                3500|          High|  Dr Anita Mehta|     Neurology|  Hyderabad|            2000|       311|       8000|         UPI|       Pending|           YES|
# |      20|      206|      1020| Lakshmi Rao|Chennai| 35|Female|    Silver|       2023-08-14|       Adult|                low|2024-03-10|     Pending|          2|                3000|          High|Dr Joseph Mathew|    Cardiology|    Chennai|            1300|       320|       5300|         UPI|       Pending|            NO|
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+

# %%
final_df.filter(
    (col("visit_status") == "Cancelled") &
    (col("payment_status") == "Cancelled")
).show()
# Out:
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+-------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# |visit_id|doctor_id|patient_id|   full_name|   city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|  doctor_name|specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+-------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+
# |      16|      207|      1016| Ayesha Khan|Kolkata| 27|Female|    Bronze|       2023-06-20|       Young|                low|2024-03-08|   Cancelled|          2|                3000|           Low|Dr Fatima Ali|   Dermatology|    Kolkata|             850|       316|       4850|        Cash|     Cancelled|            NO|
# |       7|      207|      1007|Vikram Singh|Chennai| 45|  Male|    Bronze|       2023-03-20|      Senior|                low|2024-03-04|   Cancelled|          1|                2500|           Low|Dr Fatima Ali|   Dermatology|    Kolkata|             850|       307|       2850|        Cash|     Cancelled|            NO|
# +--------+---------+----------+------------+-------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+-------------+--------------+-----------+----------------+----------+-----------+------------+--------------+--------------+

# %%
final_df.groupBy(
    "patient_id",
    "full_name"
).count().filter(
    col("count") > 1
).show()
# Out:
# +----------+------------+-----+
# |patient_id|   full_name|count|
# +----------+------------+-----+
# |      1001|  Aarav Khan|    2|
# |      1003| Rahul Mehta|    2|
# |      1006|  Ananya Das|    2|
# |      1009|  Farhan Ali|    2|
# |      1014|Kavya Sharma|    2|
# +----------+------------+-----+

# %%
patients_df.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Hyderabad|    3|
# |Bengaluru|    2|
# |   Mumbai|    2|
# |    Delhi|    2|
# |Ahmedabad|    2|
# |  Kolkata|    2|
# |  Chennai|    3|
# |    Kochi|    2|
# |     Pune|    1|
# |  Lucknow|    1|
# +---------+-----+

# %%
patients_df.groupBy("membership").count().show()
# Out:
# +----------+-----+
# |membership|count|
# +----------+-----+
# |      Gold|    8|
# |    Silver|    8|
# |    Bronze|    4|
# +----------+-----+

# %%
doctors_df.groupBy("specialization").count().show()
# Out:
# +----------------+-----+
# |  specialization|count|
# +----------------+-----+
# |      Cardiology|    2|
# |     Dermatology|    2|
# |     Orthopedics|    2|
# |      Pediatrics|    1|
# |       Neurology|    2|
# |General Medicine|    1|
# +----------------+-----+

# %%
visits_df.groupBy("visit_status").count().show()
# Out:
# +------------+-----+
# |visit_status|count|
# +------------+-----+
# |   Completed|   20|
# |     Pending|    3|
# |   Cancelled|    2|
# +------------+-----+

# %%
payments_df.groupBy("payment_mode").count().show()
# Out:
# +------------+-----+
# |payment_mode|count|
# +------------+-----+
# |         UPI|   11|
# | Credit Card|    6|
# |        Cash|    5|
# |  Debit Card|    3|
# +------------+-----+

# %%
payments_df.agg(
    sum("bill_amount")
).show()
# Out:
# +----------------+
# |sum(bill_amount)|
# +----------------+
# |          133600|
# +----------------+

# %%
payments_df.agg(
    avg("bill_amount")
).show()
# Out:
# +----------------+
# |avg(bill_amount)|
# +----------------+
# |          5344.0|
# +----------------+

# %%
final_df.groupBy("city").agg(
    sum("bill_amount").alias("total_revenue")
).show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Hyderabad|        31100|
# |   Mumbai|        18400|
# |Bengaluru|         7600|
# |    Delhi|         5800|
# |Ahmedabad|        10600|
# |  Kolkata|        18050|
# |  Chennai|        16150|
# |    Kochi|        13300|
# |     Pune|         2700|
# |  Lucknow|         9900|
# +---------+-------------+

# %%
final_df.groupBy("specialization").agg(
    sum("bill_amount").alias("total_revenue")
).show()
# Out:
# +----------------+-------------+
# |  specialization|total_revenue|
# +----------------+-------------+
# |     Orthopedics|        23800|
# |      Cardiology|        34700|
# |     Dermatology|        18100|
# |      Pediatrics|         5800|
# |       Neurology|        43800|
# |General Medicine|         7400|
# +----------------+-------------+

# %%
patients_df.createOrReplaceTempView("patients")

doctors_df.createOrReplaceTempView("doctors")

visits_df.createOrReplaceTempView("visits")

payments_df.createOrReplaceTempView("payments")

final_df.createOrReplaceTempView("hospital_data")

# %%
# %sql
SELECT * FROM patients;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patient_id</th><th>full_name</th><th>city</th><th>age</th><th>gender</th><th>membership</th><th>registration_date</th><th>age_category</th><th>membership_priority</th></tr></thead><tbody><tr><td>1001</td><td>Aarav Khan</td><td>Hyderabad</td><td>29</td><td>Male</td><td>Gold</td><td>2023-01-10</td><td>Young</td><td>high</td></tr><tr><td>1002</td><td>Priya Reddy</td><td>Bengaluru</td><td>34</td><td>Female</td><td>Silver</td><td>2023-01-15</td><td>Adult</td><td>low</td></tr><tr><td>1003</td><td>Rahul Mehta</td><td>Mumbai</td><td>41</td><td>Male</td><td>Gold</td><td>2023-02-02</td><td>Adult</td><td>high</td></tr><tr><td>1004</td><td>Sneha Kapoor</td><td>Delhi</td><td>26</td><td>Female</td><td>Bronze</td><td>2023-02-18</td><td>Young</td><td>low</td></tr><tr><td>1005</td><td>Kiran Patel</td><td>Ahmedabad</td><td>37</td><td>Male</td><td>Silver</td><td>2023-03-01</td><td>Adult</td><td>low</td></tr><tr><td>1006</td><td>Ananya Das</td><td>Kolkata</td><td>31</td><td>Female</td><td>Gold</td><td>2023-03-12</td><td>Adult</td><td>high</td></tr><tr><td>1007</td><td>Vikram Singh</td><td>Chennai</td><td>45</td><td>Male</td><td>Bronze</td><td>2023-03-20</td><td>Senior</td><td>low</td></tr><tr><td>1008</td><td>Meera Nair</td><td>Kochi</td><td>28</td><td>Female</td><td>Silver</td><td>2023-04-05</td><td>Young</td><td>low</td></tr><tr><td>1009</td><td>Farhan Ali</td><td>Hyderabad</td><td>39</td><td>Male</td><td>Gold</td><td>2023-04-15</td><td>Adult</td><td>high</td></tr><tr><td>1010</td><td>Divya Menon</td><td>Bengaluru</td><td>33</td><td>Female</td><td>Silver</td><td>2023-04-21</td><td>Adult</td><td>low</td></tr><tr><td>1011</td><td>Arjun Iyer</td><td>Chennai</td><td>52</td><td>Male</td><td>Gold</td><td>2023-05-01</td><td>Senior</td><td>high</td></tr><tr><td>1012</td><td>Neha Gupta</td><td>Delhi</td><td>25</td><td>Female</td><td>Bronze</td><td>

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>full_name</th><th>total_visits</th></tr></thead><tbody><tr><td>Rahul Mehta</td><td>2</td></tr><tr><td>Aarav Khan</td><td>2</td></tr><tr><td>Priya Reddy</td><td>1</td></tr><tr><td>Sneha Kapoor</td><td>1</td></tr><tr><td>Kiran Patel</td><td>1</td></tr><tr><td>Ananya Das</td><td>2</td></tr><tr><td>Vikram Singh</td><td>1</td></tr><tr><td>Farhan Ali</td><td>2</td></tr><tr><td>Meera Nair</td><td>1</td></tr><tr><td>Divya Menon</td><td>1</td></tr><tr><td>Neha Gupta</td><td>1</td></tr><tr><td>Arjun Iyer</td><td>1</td></tr><tr><td>Nikhil Verma</td><td>1</td></tr><tr><td>Kavya Sharma</td><td>2</td></tr><tr><td>Sanjay Rao</td><td>1</td></tr><tr><td>Ayesha Khan</td><td>1</td></tr><tr><td>Manish Yadav</td><td>1</td></tr><tr><td>Pooja Shah</td><td>1</td></tr><tr><td>Rohan Nair</td><td>1</td></tr><tr><td>Lakshmi Rao</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT payment_mode,
AVG(bill_amount) AS avg_bill
FROM hospital_data
GROUP BY payment_mode;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_mode</th><th>avg_bill</th></tr></thead><tbody><tr><td>Credit Card</td><td>6400.0</td></tr><tr><td>UPI</td><td>5272.727272727273</td></tr><tr><td>Cash</td><td>4260.0</td></tr><tr><td>Debit Card</td><td>5300.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT full_name,
SUM(bill_amount) AS total_bill
FROM hospital_data
GROUP BY full_name
HAVING SUM(bill_amount) > 10000;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>full_name</th><th>total_bill</th></tr></thead><tbody><tr><td>Rahul Mehta</td><td>12900</td></tr><tr><td>Aarav Khan</td><td>13200</td></tr><tr><td>Ananya Das</td><td>13200</td></tr></tbody></table></div>

# %%
from pyspark.sql.window import Window

window_city = Window.partitionBy("city").orderBy(desc("bill_amount"))

final_df.withColumn(
    "rank",
    rank().over(window_city)
).show()
# Out:
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+----+
# |visit_id|doctor_id|patient_id|   full_name|     city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|     doctor_name|  specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|rank|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+----+
# |       5|      206|      1005| Kiran Patel|Ahmedabad| 37|  Male|    Silver|       2023-03-01|       Adult|                low|2024-03-03|   Completed|          2|                3000|        Medium|Dr Joseph Mathew|      Cardiology|    Chennai|            1300|       305|       5300|  Debit Card|          Paid|            NO|   1|
# |      18|      206|      1018|  Pooja Shah|Ahmedabad| 32|Female|    Silver|       2023-07-18|       Adult|                low|2024-03-09|   Completed|          2|                3000|        Medium|Dr Joseph Mathew|      Cardiology|    Chennai|            1300|       318|       5300|         UPI|          Paid|            NO|   1|
# |      10|      202|      1010| Divya Menon|Bengaluru| 33|Female|    Silver|       2023-04-21|       Adult|                low|2024-03-05|   Completed|          2|                3000|        Medium|  Dr Kavita Iyer|     Dermatology|  Bengaluru|             800
1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|       Adult|               high|2024-03-03|   Completed|          4|                4000|        Medium|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|       306|      10000| Credit Card|          Paid|           YES|   1|
# |      16|      207|      1016| Ayesha Khan|  Kolkata| 27|Female|    Bronze|       2023-06-20|       Young|                low|2024-03-08|   Cancelled|          2|                3000|           Low|   Dr Fatima Ali|     Dermatology|    Kolkata|             850|       316|       4850|        Cash|     Cancelled|            NO|   2|
# |      23|      201|      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|       Adult|               high|2024-03-12|   Completed|          1|                2500|        Medium|Dr Sameer Sharma|      Cardiology|  Hyderabad|            1200|       323|       3200|        Cash|          Paid|            NO|   3|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+----+
# only showing top 20 rows

# %%
doctor_rev = final_df.groupBy(
    "specialization",
    "doctor_name"
).agg(
    sum("bill_amount").alias("revenue")
)

window_spec = Window.partitionBy(
    "specialization"
).orderBy(desc("revenue"))

doctor_rev.withColumn(
    "rank",
    rank().over(window_spec)
).show()
# Out:
# +----------------+----------------+-------+----+
# |  specialization|     doctor_name|revenue|rank|
# +----------------+----------------+-------+----+
# |      Cardiology|Dr Sameer Sharma|  18800|   1|
# |      Cardiology|Dr Joseph Mathew|  15900|   2|
# |     Dermatology|  Dr Kavita Iyer|  10400|   1|
# |     Dermatology|   Dr Fatima Ali|   7700|   2|
# |General Medicine| Dr Ganesh Patil|   7400|   1|
# |       Neurology|  Dr Anita Mehta|  26000|   1|
# |       Neurology|   Dr Leela Nair|  17800|   2|
# |     Orthopedics|   Dr Imran Khan|  13000|   1|
# |     Orthopedics|   Dr Arvind Rao|  10800|   2|
# |      Pediatrics| Dr Ramesh Reddy|   5800|   1|
# +----------------+----------------+-------+----+

# %%
window_city2 = Window.partitionBy("city").orderBy(desc("bill_amount"))

final_df.withColumn(
    "row_num",
    row_number().over(window_city2)
).filter(
    col("row_num") == 1
).show()
# Out:
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+-------+
# |visit_id|doctor_id|patient_id|   full_name|     city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|     doctor_name|  specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|row_num|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+-------+
# |       5|      206|      1005| Kiran Patel|Ahmedabad| 37|  Male|    Silver|       2023-03-01|       Adult|                low|2024-03-03|   Completed|          2|                3000|        Medium|Dr Joseph Mathew|      Cardiology|    Chennai|            1300|       305|       5300|  Debit Card|          Paid|            NO|      1|
# |      10|      202|      1010| Divya Menon|Bengaluru| 33|Female|    Silver|       2023-04-21|       Adult|                low|2024-03-05|   Completed|          2|                3000|        Medium|  Dr Kavita Iyer|     Dermatology|  Bengaluru|             800|       310|       4800| Credit Card|          Paid|            NO|      1|
# |      11|      205|      1011|  Arjun Iyer|  Chennai| 52|  Male|      Gold|       2023-05-01|      Senior|               high|2024-03-06|     Pending|          3|                3500|          High|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|       311|       8000|         UPI|       Pending|           YES|      1|
# |       4|      204|      1004|Sneha Kapoor|    Delhi| 26|Female|    Bronze|       2023-02-18|       Young|                low|2024-03-02|     Pending|          1|                2500|          High| Dr Ramesh Reddy|      Pediatrics|      Delhi|             900|       304|       2900|         UPI|       Pending|            NO|      1|
# |      21|      205|      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|       Young|               high|2024-03-11|   Completed|          3|                3500|        Medium|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|       321|       8000|         UPI|          Paid|           YES|      1|
# |      19|      209|      1019|  Rohan Nair|    Kochi| 40|  Male|      Gold|       2023-08-01|       Adult|               high|2024-03-10|   Completed|          3|                3500|        Medium|   Dr Leela Nair|       Neurology|      Kochi|            1900|       319|       7900|  Debit Card|          Paid|           YES|      1|
# |       6|      205|      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|       Adult|               high|2024-03-03|   Completed|          4|                4000|        Medium|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|       306|      10000| Credit Card|          Paid|           YES|      1|
# |      17|      209|      1017|Manish Yadav|  Lucknow| 44|  Male|      Gold|       2023-07-05|       Adult|               high|2024-03-09|   Completed|          4|                4000|        Medium|   Dr Leela Nair|       Neurology|      Kochi|            1900|       317|       9900| Credit Card|          Paid|           YES|      1|
# |       3|      203|      1003| Rahul Mehta|   Mumbai| 41|  Male|      Gold|       2023-02-02|       Adult|               high|2024-03-02|   Completed|          3|                3500|        Medium|   Dr Imran Khan|     Orthopedics|     Mumbai|            1500|       303|       7500|        Cash|          Paid|           YES|      1|
# |      15|      210|      1015|Nikhil Verma|     Pune| 36|  Male|    Silver|       2023-06-12|       Adult|                low|2024-03-08|   Completed|          1|                2500|        Medium| Dr Ganesh Patil|General Medicine|       Pune|             700|       315|       2700|  Debit Card|          Paid|            NO|      1|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+-------+

# %%
window_dense = Window.partitionBy(
    "specialization"
).orderBy(desc("consultation_fee"))

doctors_df.withColumn(
    "dense_rank",
    dense_rank().over(window_dense)
).show()
# Out:
# +---------+----------------+----------------+-----------+----------------+----------+
# |doctor_id|     doctor_name|  specialization|doctor_city|consultation_fee|dense_rank|
# +---------+----------------+----------------+-----------+----------------+----------+
# |      206|Dr Joseph Mathew|      Cardiology|    Chennai|            1300|         1|
# |      201|Dr Sameer Sharma|      Cardiology|  Hyderabad|            1200|         2|
# |      207|   Dr Fatima Ali|     Dermatology|    Kolkata|             850|         1|
# |      202|  Dr Kavita Iyer|     Dermatology|  Bengaluru|             800|         2|
# |      210| Dr Ganesh Patil|General Medicine|       Pune|             700|         1|
# |      205|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|         1|
# |      209|   Dr Leela Nair|       Neurology|      Kochi|            1900|         2|
# |      203|   Dr Imran Khan|     Orthopedics|     Mumbai|            1500|         1|
# |      208|   Dr Arvind Rao|     Orthopedics|  Bengaluru|            1400|         2|
# |      204| Dr Ramesh Reddy|      Pediatrics|      Delhi|             900|         1|
# +---------+----------------+----------------+-----------+----------------+----------+

# %%
doctor_revenue = final_df.groupBy(
    "doctor_name"
).agg(
    sum("bill_amount").alias("revenue")
)

window_doc = Window.orderBy(desc("revenue"))

doctor_revenue.withColumn(
    "rank",
    dense_rank().over(window_doc)
).filter(
    col("rank") <= 2
).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +----------------+-------+----+
# |     doctor_name|revenue|rank|
# +----------------+-------+----+
# |  Dr Anita Mehta|  26000|   1|
# |Dr Sameer Sharma|  18800|   2|
# +----------------+-------+----+

# %%
window_run = Window.orderBy("visit_date")

daily_rev = final_df.groupBy(
    "visit_date"
).agg(
    sum("bill_amount").alias("daily_revenue")
)

daily_rev.withColumn(
    "running_total",
    sum("daily_revenue").over(window_run)
).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +----------+-------------+-------------+
# |visit_date|daily_revenue|running_total|
# +----------+-------------+-------------+
# |2024-03-01|         8000|         8000|
# |2024-03-02|        10400|        18400|
# |2024-03-03|        15300|        33700|
# |2024-03-04|         8250|        41950|
# |2024-03-05|         8000|        49950|
# |2024-03-06|        10900|        60850|
# |2024-03-07|        12700|        73550|
# |2024-03-08|         7550|        81100|
# |2024-03-09|        15200|        96300|
# |2024-03-10|        13200|       109500|
# |2024-03-11|        13400|       122900|
# |2024-03-12|         7900|       130800|
# |2024-03-13|         2800|       133600|
# +----------+-------------+-------------+

# %%
window_doc_run = Window.partitionBy(
    "doctor_name"
).orderBy("visit_date")

final_df.withColumn(
    "running_total",
    sum("bill_amount").over(window_doc_run)
).show()
# Out:
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+-------------+
# |visit_id|doctor_id|patient_id|   full_name|     city|age|gender|membership|registration_date|age_category|membership_priority|visit_date|visit_status|tests_count|estimated_total_bill|visit_priority|     doctor_name|  specialization|doctor_city|consultation_fee|payment_id|bill_amount|payment_mode|payment_status|high_bill_flag|running_total|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+-------------+
# |       6|      205|      1006|  Ananya Das|  Kolkata| 31|Female|      Gold|       2023-03-12|       Adult|               high|2024-03-03|   Completed|          4|                4000|        Medium|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|       306|      10000| Credit Card|          Paid|           YES|        10000|
# |      11|      205|      1011|  Arjun Iyer|  Chennai| 52|  Male|      Gold|       2023-05-01|      Senior|               high|2024-03-06|     Pending|          3|                3500|          High|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|       311|       8000|         UPI|       Pending|           YES|        18000|
# |      21|      205|      1001|  Aarav Khan|Hyderabad| 29|  Male|      Gold|       2023-01-10|       Young|               high|2024-03-11|   Completed|          3|                3500|        Medium|  Dr Anita Mehta|       Neurology|  Hyderabad|            2000|       321|       8000|         UPI|          Paid|           YES|        26000|
# |       8|      208|      1008|  Meera Nair|    Kochi| 28|Female|    Silver|       2023-04-05|       Young|                low|2024-03-04|   Completed|          2|                3000|        Medium|   Dr Arvind Rao|     Orthopedics|  Bengaluru|            1400|       308|       5400|         UPI|          Paid|            NO|         5400|
# |      22|      208|      1003| Rahul Mehta|   Mumbai| 41|  Male|      Gold|       2023-02-02|       Adult|               high|2024-03-11|   Completed|          2|                3000|        Medium|   Dr Arvind Rao|     Orthopedics|  Bengaluru|            1400|       322|       5400| Credit Card|          Paid|            NO|        10800|
# |       7|      207|      1007|Vikram Singh|  Chennai| 45|  Male|    Bronze|       2023-03-20|      Senior|                low|2024-03-04|   Cancelled|          1|                2500|           Low|   Dr Fatima Ali|     Dermatology|    Kolkata|             850|       307|       2850|        Cash|     Cancelled|            NO|         2850|
# |      16|      207|      1016| Ayesha Khan|  Kolkata| 27|Female|    Bronze|       2023-06-20|       Young|                low|2024-03-08|   Cancelled|          2|                3000|           Low|   Dr Fatima Ali|     Dermatology|    Kolkata|             850|       316|       4850|        Cash|     Cancelled|            NO|         7700|
# |      15|      210|      1015|Nikhil Verma|     Pune| 36|  Male|    Silver|       2023-06-12|       Adult|                low|2024-03-08|   Completed|          1|                2500|        Medium| Dr Ganesh Patil|General Medicine|       Pune|             700|       315|       2700|  Debit Card|          Paid|            NO|         2700|
# +--------+---------+----------+------------+---------+---+------+----------+-----------------+------------+-------------------+----------+------------+-----------+--------------------+--------------+----------------+----------------+-----------+----------------+----------+-----------+------------+--------------+--------------+-------------+
# only showing top 20 rows

# %%
city_rev = final_df.groupBy("city").agg(
    sum("bill_amount").alias("revenue")
)

window_city_rank = Window.orderBy(desc("revenue"))

city_rev.withColumn(
    "rank",
    rank().over(window_city_rank)
).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +---------+-------+----+
# |     city|revenue|rank|
# +---------+-------+----+
# |Hyderabad|  31100|   1|
# |   Mumbai|  18400|   2|
# |  Kolkata|  18050|   3|
# |  Chennai|  16150|   4|
# |    Kochi|  13300|   5|
# |Ahmedabad|  10600|   6|
# |  Lucknow|   9900|   7|
# |Bengaluru|   7600|   8|
# |    Delhi|   5800|   9|
# |     Pune|   2700|  10|
# +---------+-------+----+

# %%
spec_rev = final_df.groupBy(
    "specialization"
).agg(
    sum("bill_amount").alias("revenue")
)

window_spec_rank = Window.orderBy(desc("revenue"))

spec_rev.withColumn(
    "rank",
    rank().over(window_spec_rank)
).show()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# +----------------+-------+----+
# |  specialization|revenue|rank|
# +----------------+-------+----+
# |       Neurology|  43800|   1|
# |      Cardiology|  34700|   2|
# |     Orthopedics|  23800|   3|
# |     Dermatology|  18100|   4|
# |General Medicine|   7400|   5|
# |      Pediatrics|   5800|   6|
# +----------------+-------+----+

# %%
window_payment = Window.partitionBy(
    "payment_mode"
).orderBy(desc("bill_amount"))

payments_df.withColumn(
    "row_num",
    row_number().over(window_payment)
).filter(
    col("row_num") == 1
).show()
# Out:
# +----------+--------+-----------+------------+--------------+--------------+-------+
# |payment_id|visit_id|bill_amount|payment_mode|payment_status|high_bill_flag|row_num|
# +----------+--------+-----------+------------+--------------+--------------+-------+
# |       303|       3|       7500|        Cash|          Paid|           YES|      1|
# |       306|       6|      10000| Credit Card|          Paid|           YES|      1|
# |       319|      19|       7900|  Debit Card|          Paid|           YES|      1|
# |       311|      11|       8000|         UPI|       Pending|           YES|      1|
# +----------+--------+-----------+------------+--------------+--------------+-------+

# %%
final_df.write.format("delta") \
.mode("overwrite") \
.saveAsTable("hospital_final_delta")

# %%
# %sql
INSERT INTO hospital_final_delta
VALUES
(
    26,                         -- visit_id
    1002,                       -- patient_id
    201,                        -- doctor_id
    'Priya Reddy',              -- full_name
    'Bengaluru',                -- city
    34,                         -- age
    'Female',                   -- gender
    'Silver',                   -- membership
    DATE('2023-01-15'),         -- registration_date
    'Adult',                    -- age_category
    2,                          -- membership_priority
    DATE('2024-03-14'),         -- visit_date
    'Completed',                -- visit_status
    2,                          -- tests_count
    3000,                       -- estimated_total_bill
    'Medium',                   -- visit_priority
    'Dr Sameer Sharma',         -- doctor_name
    'Cardiology',               -- specialization
    'Hyderabad',                -- doctor_city
    1200,                       -- consultation_fee
    326,                        -- payment_id
    5500,                       -- bill_amount
    'UPI',                      -- payment_mode
    'Paid',                     -- payment_status
    'NO'                        -- high_bill_flag
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
UPDATE hospital_final_delta
SET visit_status = 'Completed'
WHERE visit_id = 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
UPDATE hospital_final_delta
SET payment_status = 'Paid'
WHERE payment_id = 320;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
DELETE FROM hospital_final_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

# %%
final_df.filter(
    col("visit_status") == "Completed"
).write.format("delta") \
.mode("overwrite") \
.saveAsTable("completed_visits_delta")

# %%
# %sql
DESCRIBE HISTORY hospital_final_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>queryHistoryStatementId</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>6</td><td>2026-05-06T06:20:10.000Z</td><td>145705804971194</td><td>azuser5813_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(2784658541542980)</td><td>edd27636-1a39-4c4c-916a-0f8b4933aa3c</td><td>0506-035947-s569xvo0-v2n</td><td>5</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 2, numRemovedBytes -> 14489, p25FileSize -> 8217, numDeletionVectorsRemoved -> 1, minFileSize -> 8217, numAddedFiles -> 1, maxFileSize -> 8217, p75FileSize -> 8217, p50FileSize -> 8217, numAddedBytes -> 8217)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr><tr><td>5</td><td>2026-05-06T06:20:09.000Z</td><td>145705804971194</td><td>azuser5813_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>DELETE</td><td>Map(predicate -> ["(visit_status#19209 = Cancelled)"])</td><td>null</td><td>List(2784658541542980)</td><td>edd27636-1a39-4c4c-916a-0f8b4933aa3c</td><td>0506-035947-s569xvo0-v2n</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 1, numAddedChangeFiles -> 0, executionTimeMs -> 1200, numDeletionVectorsUpdated -> 1, numDeletedRows -> 2, scanTimeMs -> 852, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 348)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr><tr><td>4</td><td>2026-05-06T06:18:49.000Z</td><td>145705804971194</td><td>azuser5813_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>UPDATE</td><td>Map(predicate -> ["(payment_id#18240L = 320)"])</td><td>null</td><td>List(2784658541542980)</td><td>906a563a-06c7-4932-948b-35ebb7edbe79</td><td>0506-035947-s569xvo0-v2n</td><td>3</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2269, numDeletionVectorsUpdated -> 0, scanTimeMs -> 926, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 6090, rewriteTimeMs -> 1343)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr><tr><td>3</td><td>2026-05-06T06:18:45.000Z</td><td>145705804971194</td><td>azuser5813_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(2784658541542980)</td><td>416bcdca-5104-419c-a408-79a4c4c522e1</td><td>0506-035947-s569xvo0-v2n</td><td>2</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 10, numRemovedBytes -> 66430, p25FileSize -> 8399, numDeletionVectorsRemoved -> 1, minFileSize -> 8399, numAddedFiles -> 1, maxFileSize -> 8399, p75FileSize -> 8399, p50FileSize -> 8399, numAddedBytes -> 8399)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr><tr><td>2</td><td>2026-05-06T06:18:42.000Z</td><td>145705804971194</td><td>azuser5813_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>UPDATE</td><td>Map(predicate -> ["(visit_id#16864L = 20)"])</td><td>null</td><td>List(2784658541542980)</td><td>416bcdca-5104-419c-a408-79a4c4c522e1</td><td>0506-035947-s569xvo0-v2n</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTi ...

# %%
# %sql
SELECT *
FROM hospital_final_delta VERSION AS OF 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>visit_id</th><th>doctor_id</th><th>patient_id</th><th>full_name</th><th>city</th><th>age</th><th>gender</th><th>membership</th><th>registration_date</th><th>age_category</th><th>membership_priority</th><th>visit_date</th><th>visit_status</th><th>tests_count</th><th>estimated_total_bill</th><th>visit_priority</th><th>doctor_name</th><th>specialization</th><th>doctor_city</th><th>consultation_fee</th><th>payment_id</th><th>bill_amount</th><th>payment_mode</th><th>payment_status</th><th>high_bill_flag</th></tr></thead><tbody><tr><td>22</td><td>208</td><td>1003</td><td>Rahul Mehta</td><td>Mumbai</td><td>41</td><td>Male</td><td>Gold</td><td>2023-02-02</td><td>Adult</td><td>high</td><td>2024-03-11</td><td>Completed</td><td>2</td><td>3000</td><td>Medium</td><td>Dr Arvind Rao</td><td>Orthopedics</td><td>Bengaluru</td><td>1400</td><td>322</td><td>5400</td><td>Credit Card</td><td>Paid</td><td>NO</td></tr><tr><td>23</td><td>201</td><td>1006</td><td>Ananya Das</td><td>Kolkata</td><td>31</td><td>Female</td><td>Gold</td><td>2023-03-12</td><td>Adult</td><td>high</td><td>2024-03-12</td><td>Completed</td><td>1</td><td>2500</td><td>Medium</td><td>Dr Sameer Sharma</td><td>Cardiology</td><td>Hyderabad</td
</td><td>Kolkata</td><td>31</td><td>Female</td><td>Gold</td><td>2023-03-12</td><td>Adult</td><td>high</td><td>2024-03-03</td><td>Completed</td><td>4</td><td>4000</td><td>Medium</td><td>Dr Anita Mehta</td><td>Neurology</td><td>Hyderabad</td><td>2000</td><td>306</td><td>10000</td><td>Credit Card</td><td>Paid</td><td>YES</td></tr><tr><td>8</td><td>208</td><td>1008</td><td>Meera Nair</td><td>Kochi</td><td>28</td><td>Female</td><td>Silver</td><td>2023-04-05</td><td>Young</td><td>low</td><td>2024-03-04</td><td>Completed</td><td>2</td><td>3000</td><td>Medium</td><td>Dr Arvind Rao</td><td>Orthopedics</td><td>Bengaluru</td><td>1400</td><td>308</td><td>5400</td><td>UPI</td><td>Paid</td><td>NO</td></tr><tr><td>9</td><td>201</td><td>1009</td><td>Farhan Ali</td><td>Hyderabad</td><td>39</td><td>Male</td><td>Gold</td><td>2023-04-15</td><td>Adult</td><td>high</td><td>2024-03-05</td><td>Completed</td><td>1</td><td>2500</td><td>Medium</td><td>Dr Sameer Sharma</td><td>Cardiology</td><td>Hyderabad</td><td>1200</td><td>309</td><td>3200</td><td>UPI</t ...

# %%
# %sql
VACUUM hospital_final_delta RETAIN 168 HOURS DRY RUN;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody></tbody></table></div>

# %%
daily_visits_data = [
(26,1002,201,"2024-03-14","Completed",2),
(27,1005,210,"2024-03-14","Completed",1),
(11,1011,205,"2024-03-06","Completed",3),
(20,1020,206,"2024-03-10","Completed",2),
(28,1018,203,"2024-03-15","Pending",2)
]

daily_visits_columns = [
"visit_id","patient_id","doctor_id",
"visit_date","visit_status","tests_count"
]

daily_visits_df = spark.createDataFrame(
    daily_visits_data,
    daily_visits_columns
)

# %%
visits_df.write.format("delta") \
.mode("overwrite") \
.saveAsTable("visits_target")

# %%
daily_visits_df.createOrReplaceTempView(
    "daily_updates"
)

# %%
# %sql
MERGE INTO visits_target t
USING daily_updates s
ON t.visit_id = s.visit_id

WHEN MATCHED THEN
  UPDATE SET
    t.visit_status = s.visit_status,
    t.tests_count = s.tests_count

WHEN NOT MATCHED THEN
  INSERT (visit_id, patient_id, doctor_id, visit_date, visit_status, tests_count)
  VALUES (s.visit_id, s.patient_id, s.doctor_id, s.visit_date, s.visit_status, s.tests_count)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>2</td><td>0</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM visits_target
WHERE visit_id IN (11,20);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>visit_id</th><th>patient_id</th><th>doctor_id</th><th>visit_date</th><th>visit_status</th><th>tests_count</th><th>estimated_total_bill</th><th>visit_priority</th></tr></thead><tbody><tr><td>20</td><td>1020</td><td>206</td><td>2024-03-10</td><td>Completed</td><td>2</td><td>3000</td><td>High</td></tr><tr><td>11</td><td>1011</td><td>205</td><td>2024-03-06</td><td>Completed</td><td>3</td><td>3500</td><td>High</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM visits_target
WHERE visit_id IN (26,27,28);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>visit_id</th><th>patient_id</th><th>doctor_id</th><th>visit_date</th><th>visit_status</th><th>tests_count</th><th>estimated_total_bill</th><th>visit_priority</th></tr></thead><tbody><tr><td>26</td><td>1002</td><td>201</td><td>2024-03-14</td><td>Completed</td><td>2</td><td>null</td><td>null</td></tr><tr><td>27</td><td>1005</td><td>210</td><td>2024-03-14</td><td>Completed</td><td>1</td><td>null</td><td>null</td></tr><tr><td>28</td><td>1018</td><td>203</td><td>2024-03-15</td><td>Pending</td><td>2</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
describe history visits_target
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>queryHistoryStatementId</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>1</td><td>2026-05-06T06:32:02.000Z</td><td>145705804971194</td><td>azuser5813_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>MERGE</td><td>Map(predicate -> ["(visit_id#23248L = visit_id#23215L)"], clusterBy -> [], matchedPredicates -> [{"actionType":"update"}], statsOnLoad -> false, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(2784658541542980)</td><td>aa4d7c2a-a11e-44c4-8cc3-2ea52c611f3b</td><td>0506-035947-s569xvo0-v2n</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 5, numTargetBytesAdded -> 11184, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 1, numTargetRowsMatchedUpdated -> 2, executionTimeMs -> 2792, materializeSourceTimeMs -> 288, numTargetRowsInserted -> 3, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 1101, numTargetRowsUpdated -> 2, numOutputRows -> 5, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 5, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1355)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr><tr><td>0</td><td>2026-05-06T06:28:03.000Z</td><td>145705804971194</td><td>azuser5813_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true"}, statsOnLoad -> true)</td><td>null</td><td>List(2784658541542980)</td><td>211f006a-725c-4522-8d72-f6cc01737b4f</td><td>0506-035947-s569xvo0-v2n</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numRemovedFiles -> 0, numRemovedBytes -> 0, numDeletionVectorsRemoved -> 0, numOutputRows -> 25, numOutputBytes -> 2889)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr></tbody></table></div>
